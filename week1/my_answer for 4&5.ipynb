# %% [markdown]
# problem 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
a=np.loadtxt('Data1_1.txt') #read data

# %%
plt.figure(1) #picture data Data1_1.txt
plt.plot(a[:,0],a[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(2) #repicture data Data1_1.txt
plt.plot(np.log(a[:,0]),a[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# problem 5

# %%
from mpl_toolkits import mplot3d

# %%
b=np.loadtxt('Data1_2.txt') #read the data
maxindex=np.argmax(b[:,2]) #found the index of the maximal number
b[maxindex]
# Out:
# array([4., 3., 1.])

# %%
ax=plt.axes(projection='3d')  #picture the data 
plt.rcParams['figure.figsize']=(20.0,10.0)
ax.scatter3D(b[:,0],b[:,1],b[:,2]) 
ax.text(4,3,1,'maximum',c='r') #annotate the maximum
plt.show()
